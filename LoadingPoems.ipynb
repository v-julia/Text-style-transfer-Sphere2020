# %%
from lxml import etree, html as lhtml
from bs4 import BeautifulSoup
import urllib3
import urllib.parse
import pandas as pd
import re
import tqdm

# %%
import nltk.data

# %%
tokenizer = nltk.data.load('tokenizers/punkt/russian.pickle')

# %%
shop_page = "http://stih.su/"

# %%
authors = ['ahmatova', 'cvetaeva', 'pushkin', 'esenin', 'lermontov', 'tyutchev', 'majakovskij', 'fet-aa']

# %%
def get_poems_urls(author_soup):
    poems_hrefs = []
    all_poems_h2 = author_soup.find_all('h2', class_="entry-title")

    for h2_poem in all_poems_h2:
        href_poem = h2_poem.find('a')['href']
        poems_hrefs.append(href_poem)
        
        
    if len(all_poems_h2) == 0:
        all_poems_h2 = author_soup.find('div', class_="years-category")
        all_hrefs = all_poems_h2.find_all('a')
        for href in all_hrefs:
            poem_href = href['href']
            if poem_href.startswith(shop_page):
                poems_hrefs.append(poem_href)
            else:
                poems_hrefs.append(shop_page+href['href'])
    return poems_hrefs

# %%
import re
def get_poem_text(poem_url):
    response = http.request('GET', poem_url)
    c=1
    while response.status != 200 and c<=5:
        response = http.request('GET', poem_url)
        c += 1
    if response.status != 200:
        print('Can\t load the page')
    poem_soup = BeautifulSoup(response.data, "lxml")
    poem_content = poem_soup.find('div', 'entry-content')

    poem_text = ''

    poems_p = poem_content.find_all('p')

    for poem_p in poems_p:
        if poem_p.text.lower().find("год написания") != -1 or re.search(r'18[0-9]+\sг.',poem_p.text) or re.search(r'\s19[0-9]+',poem_p.text):
            print(poem_p.text)
        else:
            
            poem_text+= poem_p.text
            poem_text += '\n'

    poem_text = poem_text.lower()
    return poem_text

# %%
http = urllib3.PoolManager()

# %%
authors
# Out:
# ['ahmatova',
#  'cvetaeva',
#  'pushkin',
#  'esenin',
#  'lermontov',
#  'tyutchev',
#  'majakovskij',
#  'fet-aa']

# %%
poems = []
for author in authors:
    print(urllib.parse.urljoin(shop_page, author))
    cur_author_url = urllib.parse.urljoin(shop_page, author)
    response = http.request('GET', cur_author_url)
    c=1
    while response.status != 200 and c<=5:
        response = http.request('GET', cur_author_url)
        c += 1
    if response.status != 200:
        print('Can\t load the page')


    author_soup = BeautifulSoup(response.data, "lxml")
    poems_urls = get_poems_urls(author_soup)
    poem_texts = []
    for purl in poems_urls:
        poem_texts.append(get_poem_text(purl))
    sentences = tokenizer.tokenize(' '.join(poem_texts))
    poems.append('\n'.join(poem_texts))
    print(author, len(poem_texts), len(sentences))
# Out:
# http://stih.su/ahmatova
# ahmatova 338 1211
# http://stih.su/cvetaeva
# cvetaeva 1365 15633
# http://stih.su/pushkin
# pushkin 773 13297
# http://stih.su/esenin
# esenin 397 5258
# http://stih.su/lermontov
# lermontov 422 8868
# http://stih.su/tyutchev
# tyutchev 399 1594
# http://stih.su/majakovskij
# majakovskij 1293 29395
# http://stih.su/fet-aa
# fet-aa 906 2906

# %%
len(poems)
# Out:
# 8

# %%
for author, poem_text in zip(authors, poems):
    with open('data/'+author+'all.txt', 'w', encoding='UTF-8') as file:
        file.write(poem_text)
    file.close()

# %%
poems = []
for author in ['cvetaeva']:
    print(urllib.parse.urljoin(shop_page, author))
    cur_author_url = urllib.parse.urljoin(shop_page, author)
    response = http.request('GET', cur_author_url)
    c=1
    while response.status != 200 and c<=5:
        response = http.request('GET', cur_author_url)
        c += 1
    if response.status != 200:
        print('Can\t load the page')


    author_soup = BeautifulSoup(response.data, "lxml")
    poems_urls = get_poems_urls(author_soup)
    poem_texts = []
    for purl in poems_urls:
        poem_texts.append(get_poem_text(purl))
    sentences = tokenizer.tokenize(' '.join(poem_texts))
    poems.append('\n'.join(poem_texts))
    print(author, len(poem_texts), len(sentences))
# Out:
# http://stih.su/cvetaeva
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# …«но ведь есть каток»…
# Письмо 17 января 1910
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Феодосия, 26 декабря 1913
# Год написания: без даты
# — «Мы никого так»…
# — «Мы никогда так»…
# — «Ну, что же? Кончайте»…
# 27-го декабря 1909
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# «Да, для вас наша жизнь действительно в тумане».
# Разговор 20-гo декабря 1909
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: без даты
# Год написания: 1941
# Год написания: 1941
# Год написания: 1941
# Год написания: 1940
# Год написания: 1940
# Год написания: 1940
# Год написания: 1940
# Год написания: 1940
# Год написания: 1940
# Год написания: 1940
# Год написания: 1940
# – Через десять лет забудут!
# – Через двести – вспомнят!
# (Живой разговор летом 1928 г. Второй – я.)
# Начат 1-го августа 1928г., в Понтайяке (Жиронда)
# Кончен 15-го мая 1929г., в Медоне (девять лет с майского Перекопа)
# Переписан в эту книжку 5-го – 8-го сентября 1938г. в Dives-sur-Mer (Морском Диве) – Calvados.
# – А все ж – всю Русь-святу несет
# За пазухой…
# – Христовой.
# Многоточие, тире и перерыв строки – моя последняя проверка и окончательное утверждение.
# И, вот, двадцать лет спустя, повторяю: Христос на Руси в тот час укрывался за пазухой добровольца. Весь Христос – за тощей пазухой добровольца. Так было – и так будет – благодаря этим двум моим строкам.
# МЦ,
# Париж. 17 сентября 1938г.
# МЦ
# Париж,7 января 1939
# Год написания: 1939
# Год написания: 1939
# Год написания: 1939
# Год написания: 1939
# Год написания: 1939
# Год написания: 1939
# Год написания: 1939
# Год написания: 1939
# Год написания: 1939
# Год написания: 1939
# Год написания: 1939
# Год написания: 1939
# Чехи подходили к немцам и плевали.
# (См. мартовские газеты 1939 г.)
# Год написания: 1939
# Год написания: 1939
# Год написания: 1939
# Год написания: 1938-1939
# В Судетах, ни лесной чешской границе, офицер с 20-тью солдатами, оставив солдат в лесу, вышел на дорогу и стал стрелять в подходящих немцев. Конец его неизвестен.
# (Из сентябрьских газет 1938 г.)
# Октябрь 1938 — 17 апреля 1939
# Год написания: 1938-1939
# Год написания: 1938
# Год написания: 1938
# Год написания: 1938
# Год написания: 1938
# Год написания: 1938
# Год написания: 1937
# Год написания: 1936
# Год написания: 1936
# Год написания: 1936
# Год написания: 1936
# Год написания: 1936
# Год написания: 1936
# Год написания: 1936
# Год написания: 1936
# Год написания: 1936
# Год написания: 1935
# Год написания: 1935
# Год написания: 1935
# Год написания: 1935
# Год написания: 1935
# Год написания: 1935
# Год написания: 1935
# Год написания: 1935
# Год написания: 1935
# Год написания: 1935
# Год написания: 1935
# Год написания: 1935
# Год написания: 1935
# Год написания: 1935
# Год написания: 1935
# Год написания: 1935
# Год написания: 1935
# Год написания: 1935
# Апрель 1934 — июнь 1936
# Год написания: 1934-1936
# Год написания: 1934
# Год написания: 1934
# Год написания: 1934
# Год написания: 1934
# Год написания: 1934
# Год написания: 1934
# Год написания: 1934
# Год написания: 1934
# Год написания: 1934
# Год написания: 1934
# Год написания: 1934
# Год написания: 1934
# Год написания: 1934
# Год написания: 1934
# Около 15 июля 1933 — 29–30 октября 1935
# Год написания: 1933-1935
# Год написания: 1933
# Год написания: 1933
# Год написания: 1933
# Год написания: 1933
# Год написания: 1932–1935
# Год написания: 1932
# Год написания: 1932
# Год написания: 1932
# Год написания: 1932
# Год написания: 1932
# Год написания: 1932
# Год написания: 1932
# Год написания: 1932
# Год написания: 1932
# Год написания: 1932
# Год написания: 1932
# 11 сентября 1931, Медон — 21 мая 1935, Ванв
# Год написания: 1931-1935
# Медон, 26 августа 1931 — Кламар, 30 марта 1933
# Год написания: 1931-1933
# Год написания: 1931
# Год написания: 1931
# Год написания: 1931
# Год написания: 1931
# Год написания: 1931
# Год написания: 1931
# Год написания: 1931
# Год написания: 1931
# Год написания: 1931
# Год написания: 1931
# Год написания: 1931
# Год написания: 1931
# Год написания: 1930
# Год написания: 1930
# Год написания: 1929-1936
# Год написания: 1928
# Год написания: 1928
# Год написания: 1928
# Год написания: 1928
# Год написания: 1928
# Год написания: 1928
# Год написания: 1928
# Год написания: 1928
# Год написания: 1928
# Год написания: 1927
# Год написания: 1926
# Год написания: 1926
# Год написания: 1926
# Год написания: 1926
# Год написания: 1926
# Год написания: 1926
# Год написания: 1926
# Год написания: 1925
# Год написания: 1925
# Год написания: 1925
# Год написания: 1925
# Год написания: 1925
# Год написания: 1925
# Год написания: 1925
# Год написания: 1925
# Год написания: 1925
# 1uri — судья, R?hrei — яичница-болтунья, национальное блюдо; R?hr uns nicht an — не дотрагивайтесь
# 2«Человек, где ты?» (нем.)
# 3«Я наг» (нем.)
# 4NB! Лучше (прим. автора)
# 5Мой сын Георгий (Мур), родившийся в полный разгар мечты о Крысолове и первой главы его — 1-го февраля 1925 г., в воскресенье, ровно в полдень, в безумную (последнюю!) вьюгу, в избе, в деревне Вшеноры, близ Праги. МЦ.
# 6Ударение, как: Миргород, Белгород и пр. (прим. автора)
# 7«Завтра — тоже день» (нем.)
# 8Burg — по-немецки крепость. МЦ.
# 9Подразумевается: запах. МЦ.
# 10Излишество вредно (нем.)
# 11В меру! (нем.)
# 12В последующих строках ударяются слоги: первый, второй и последний (прим. автора)
# 13Убийца Коцебу (прим. автора)
# 14Позор! (нем.)
# 15Бог! (нем.)
# 16Сердечный, дорогой (нем.)
# 17Хлеб (нем.)
# 18В лето Господне (лат.)
# 19Липами (нем.)
# 20Жареная баранина (нем.)
# 21Обман и стыд! (нем.)
# 22Квартет (лат.)
# 23Будет дело! (фр.)
# 24Умри и убей! (нем.)
# 25В прошлом! (ит.)
# 26Деньги — песок (нем.)
# 27Неизвестен (нем.)
# 28Дадим — слопает, жить — значит экономить… (нем.)
# 29Утреннюю похлебку! (нем.)
# 30Нежнейший тон (ит.)
# Год написания: 1925
# Год написания: 1925
# Год написания: 1925
# Год написания: 1925
# Год написания: 1925
# Год написания: 1925
# 1 января — 1 февраля 1924
# Прага. Гора.
# Декабрь 1939. Голицыно, Дом писателей
# Год написания: 1924-1939
# Год написания: 1924
# Год написания: 1924
# Год написания: 1924
# Год написания: 1924
# Год написания: 1924
# Год написания: 1924
# Год написания: 1924
# Год написания: 1924
# Год написания: 1924
# Год написания: 1924
# Год написания: 1924
# Год написания: 1924
# Год написания: 1924
# Год написания: 1924
# Год написания: 1924
# Год написания: 1924
# Год написания: 1924
# Год написания: 1924
# Год написания: 1924
# Год написания: 1924
# Год написания: 1924
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1923
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1922
# Год написания: 1921-1922
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# 14 июля 1921
# (Не докончено за письмом.)
# Год написания: 1921
# 2 октября 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1921
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# «В гробу, в обыкновенном тeмном костюме, в устойчивых, гpyбых ботинках, подбитых железом, лежит величайший поэт революции».
# («Однодневная газета», 24 апреля 1920 г.)
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1920
# Год написания: 1919-1920
# Год написания: 1920
# Год написания: 1919–1937
# Год написания: 1919
# Год написания: 1919
# Год написания: 1919
# Год написания: 1919
# Год написания: 1919
# Год написания: 1919
# Год написания: 1919
# Год написания: 1919
# Год написания: 1919
# Год написания: 1919
# Год написания: 1919
# Год написания: 1919
# Год написания: 1919
# Год написания: 1919
# Год написания: 1919
# Год написания: 1919
# Год написания: 1919
# Год написания: 1919
# Год написания: 1919
# Год написания: 1919
# Год написания: 1919
# Год написания: 1919
# Год написания: 1919
# Год написания: 1919
# Год написания: 1919
# Год написания: 1919
# Год написания: 1919
# Год написания: 1919
# Год написания: 1919
# Год написания: 1919
# Год написания: 1919
# Год написания: 1919
# Год написания: 1919
# Год написания: 1919
# Год написания: 1919
# Год написания: 1919
# Год написания: 1919
# Год написания: 1919
# Год написания: 1919
# Год написания: 1919
# Год написания: 1919
# Год написания: 1919
# Год написания: 1919
# Год написания: 1919
# Год написания: 1919
# Год написания: 1919
# Год написания: 1919
# Год написания: 1919
# Год написания: 1919
# Год написания: 1919
# Год написания: 1919
# Год написания: 1919
# Год написания: 1919
# Год написания: 1919
# Год написания: 1919
# Год написания: 1919
# Год написания: 1919
# Год написания: 1919
# Год написания: 1919
# Год написания: 1919
# Год написания: 1919
# Год написания: 1919
# Год написания: 1918 - 1939
# (А балладу уничтожила: слабая. 1939 г.)
# Год написания: 1918
# Год написания: 1918
# Год написания: 1918
# Год написания: 1918
# Год написания: 1918
# Год написания: 1918
# Год написания: 1918
# Год написания: 1918
# (Проснулась с этими стихами 22 мая 1918)
# Год написания: 1918
# 7 мая 1918, 3-ий день Пасхи
# (а оставалось ему жить меньше трех месяцев!)
# Год написания: 1918
# Год написания: 1918
# Год написания: 1918
# Год написания: 1918
# Год написания: 1918
# Год написания: 1918
# Год написания: 1918
# Год написания: 1918
# Год написания: 1918
# Год написания: 1918
# Год написания: 1918
# Год написания: 1918
# Год написания: 1918
# Год написания: 1918
# Год написания: 1918
# Год написания: 1918
# Год написания: 1918
# Год написания: 1918
# Год написания: 1918
# Год написания: 1918
# Год написания: 1918
# Год написания: 1918
# Год написания: 1918
# Год написания: 1918
# Год написания: 1918
# Год написания: 1918
# Вербное воскресенье 1918
# 14 июля 1918
# 6 июля 1918
# 3 ноября 1918
# 9 ноября 1918
# 8 марта 191
# 9 августа 1918
# 26 августа 1918
# 14 мая 1918
# 8 октября 1918
# Сергиев день
# 1 ноября 1918
# Между 21 и 26 мая 1918
# 14 августа 1918
# 8 сентября 1918
# 9 мая 1918
# 9 ноября 1918
# Между 6 и 10 июля 1918
# 10 июля 1918
# 6 июля 1918
# 9 сентября 1918
# 9 октября 1918
# 6 июня 1918
# 14 октября 1918
# 7 мая 1918,
# третий день Пасхи
# Страстной понедельник 1918
# 9 августа 1918
# 10 апреля 1918
# Между 30 июня и 6 июля 1918
# 10 ноября 1918
# 10 ноября 1918
# 23 ноября 1918
# 17 апреля 1918
# 23 октября 1918
# Апрель 1918
# 14 августа 1918
# 20 ноября 1918
# 14 августа 1918
# 9 октября 1918
# Май 1918
# 13 мая 1918
# 1 декабря 1918
# 2 ноября 1918
# Москва, 18 января 1918
# 6 июня 1918
# 9 мая 1918
# 12 ноября 1918
# Октябрь 1918
# 27 июля 1918
# 16 августа 1918
# 3 декабря 1918
# 7 ноября 1918
# 14 ноября 1918
# Страстной понедельник 1918
# 19 ноября 1918
# 10 октября 1918
# 30 марта 1918
# NB! мои любимые.
# 2 ноября 1918
# Москва. 2 марта 1918
# Первый день весны.
# 10 ноября 1918
# 27 ноября 1918
# 20 ноября 1918
# 8 сентября 1918
# 1 Моя вторая дочь Ирина — родилась 13-го апреля 1917 г., умерла 2-го февраля 1920 г. в Сретение, от голода, в Кунцевском детском приюте.
# 3-ий день Пасхи 1918
# Июль 1918
# 10 июля 1918
# 19 февраля 1918
# 14 августа 1918
# 30 марта 1918
# 24 августа 1918
# 9 мая 1918
# 10 мая 1918
# Март 1918
# 5 ноября 1918
# 5 августа 1918
# 18 августа 1918
# 20 ноября 1918
# 15 октября 1918
# 6 июня 1918
# 27 июля 1918
# 12 августа 1918
# 9 ноября 1918
# 30 сентября 1918
# 11 января 1918
# 23 октября 1918
# 18 августа 1918
# 9 августа 1918
# 25 ноября 1918
# 22 ноября 1918
# Москва, Благовещение 1918
# — дни разгрома Дона —
# 13 января 1918
# 11 марта 1918
# Декабрь 1918
# Январь 1918
# 14 мая 1918
# 8 октября 1918
# 25 октября 1918
# Конец декабря 1918
# 12 мая 1918
# 21 мая 1918
# 9 ноября 1918
# Между 26 мая и 4 июня 1918
# 9 августа 1918
# 7 июля 1918
# 24 марта 1918
# 26 августа 1918
# 11 ноября 1918
# 17 апреля 1918
# 18 августа 1918
# 15 октября 1918
# 28 сентября 1918
# 4 сентября 1917
# 17 июля 1917
# 10 апреля 1917
# 13 мая 1917
# 25 июня 1917
# Москва, 2 апреля 1917,
# первый день Пасхи
# (Не окончено. Жаль).
# Март 1917
# 2 февраля 1917. Сретение
# 6 сентября 1917
# 20 января 1917
# 20 июня 1917
# 25 августа 1917
# 2 мая 1917
# 3 июля 1917
# 18 июня 1917
# 22 апреля 1917
# 25 апреля 1917
# 8 мая 1917
# Год написания: 1917
# Этих рук не разведу.
# Лучше буду,
# Лучше буду
# Полымем пылать в аду!
# 1917 г.
# 22 августа 1917
# Из Индии пришлите камни.
# Когда увидимся? — Во сне.
# — Как ветрено! — Привет жене,
# И той — зеленоглазой — даме.
# 1917 г.
# 22 августа 1917
# 4 декабря 1917
# 22 февраля 1917
# 19 августа 1917
# 12 декабря 1917
# 22 февраля 1917
# 7 июля 1917
# 4 сентября 1917
# Феодосия, конец Октября
# 1917 г.
# Сентябрь 1917
# (Не окончено)
# 7 июля 1917
# Феодосия, последние дни Октября
# 1917 г.
# 31 декабря 1917
# 23 августа 1917
# Огромное дыханье ветра,
# Дыханье северных садов, —
# И горестный, огромный вздох:
# — Ne laissez pas trainer mes lettres!*
# 1917 г.
# * «Не раскидывайте мои письма!» (фр.)
# Москва, 2 марта 1917
# 19 февраля 1917
# 20 августа 1917
# 1 сентября 1917
# 1 января 1917
# 14 января 1917
# 29 января 1917
# 4 декабря 1917
# — Ну, что сказали на денек вчерашний
# Российские умы?
# 1917 г.
# 9 декабря 1917
# 22 декабря 1917
# 21 мая 1917
# 31 декабря 1917
# 26 мая 1917
# 20 августа 1917
# Март 1917
# 8 июня 1917
# 4 июля 1917
# 14 мая 1917
# 21 мая 1917
# Троицын день
# 11 июня 1917
# 14 сентября 191
# 27 июля 1917
# 14 мая 1917
# 23 сентября 1917
# Длинной рукою незрячей
# Гладя раскиданный стан,
# Что на груди твоей плачет
# Твой молодой Иоанн.
# 1917 г.
# 4 апреля 1917,
# третий день Пасхи
# 10 декабря 1917
# 19 февраля 1917
# 8 января 1917
# 3 или 4 июля 1917
# 10 декабря 1917
# 10 июня 1917
# 6 июня 1917
# 21 мая 1917
# 22-27 июня 1917
# 9 апреля 1917
# 6 сентября 1917
# 19 мая 1917
# 5 июня 1917
# 4 августа 1917
# 13 июня 1917
# 30 сентября 1917
# 3 сентября 1917
# 11 июня 1917
# 18 сентября 1917
# 7 февраля 1917
# 11 июня 1917
# 10 июня 1917
# 12 апреля 1917
# 15 августа 1916
# 27 апреля 1916
# 21 ноября 1916
# 10 декабря 1916
# 15 августа 1916
# 24 марта 1916
# 9 августа 1916
# 15 ноября 1916
# 17 октября 1916
# 22 марта 1916
# 1 июля 1916
# 7 мая 1916
# 26 июня 1916
# 7 декабря 1916
# 2 июля 1916
# 2 мая 1916
# 18 февраля 1916
# 20 апреля 1916
# 29 сентября 1916
# 1 января 1917
# 11 ноября 1916
# 8 сентября 1916
# 17 февраля 1916
# 11 ноября 1916
# 25 июня 1916
# 8 июля 1916. Казанская
# 26 июля 1916
# 1 августа 1916
# 27 мая 1916
# 2 июля 1916
# 16 ноября 1916
# 1 марта 1916
# 28 апреля 1916
# 20 марта 1916
# 19 июля 1916
# 23 января 1916
# 22 октября 1916
# 17 декабря 1916
# 15 ноября 1916
# 22 июня 1916
# Москва, январь 1916
# 18 февраля 1916
# 31 марта 1916
# 8 апреля 1916
# 19 июня 1916
# 20 июля 1916
# 12 февраля 1916
# 1 мая 1916
# 8 августа 1916
# 4 марта 1916
# 26 июня 1916
# 2 августа 1916
# 16 марта 1916
# 11 апреля 1916
# 1-й день Пасхи
# 26 июля 1916
# Троицын день 1916
# 28 мая 1916
# 23 марта 1916
# 29 августа 1916
# 27 июня 1916
# 8 июля 1916. Казанская
# 2 мая 1916
# 31 марта 1916
# 12 декабря 1916
# 16 августа 1916
# 6 апреля 1916
# 24-25 марта 1916
# 8 ноября 1916
# 25 октября 1916
# 6 февраля 1916
# 24 июля 1916
# 15 апреля 1916
# 24 июня 1916
# 31 марта 1916
# 18 мая 1916
# 26 август 1916
# 10 октября 1916
# 21 сентября 1916
# 7 августа 1916
# 27 июня 1916
# 2 мая 1916
# 26 марта 1916
# 23 июня 1916
# 16 марта 1916
# 13 октября 1916
# 9 мая 1916
# 13 мая 1916
# 29, 30 марта 1916
# 2 апреля 1916
# Вербная Суббота
# 12 марта 1916
# 1 апреля 1916
# 17 марта 1916
# 5 апреля 1916
# 23 декабря 1916
# 4 апреля 1916
# 23 июля 1916
# 28 июля 1916
# 26 апреля 1916
# 17 июля 1916
# Москва
# 23 марта 1916
# 5 апреля 1916
# 15 августа 1916
# 3 июля 1916
# 28 июня 1916
# 3 октября 1915
# Вознесение 1915
# Октябрь 1915
# 22 октября 1915
# 3 мая 1915
# 14 января 1915
# 5 августа 1915
# 13 марта 1915
# 10 января 1915
# 22 сентября 1915
# 27 ноября 1915
# 28 апреля 1915
# 28 января 1915
# [1]Белой розы (модные в то время духи)
# Сентябрь 1915
# 3 мая 1915
# 5 июня 1915
# 25 сентября 1915 г.
# Москва, 20 декабря 1915
# 3 марта 1915
# 23 июня 1915
# 29 сентября 1915
# 6 июля 1915
# 26 сентября 1915
# Вознесение, 1915
# 18 декабря 1915
# 6 октября 1915
# Петербург, 31 декабря 1915
# 14 марта 1915
# 6 мая 1915
# 22 февраля 1915
# 24 сентября 1915
# 5 сентября 1915
# 14 июля 1915
# 29 сентября 1915
# Ноябрь 1915
# 9 мая 1915
# 3 января 1915
# 11 февраля 1915
# 13 июля 1914
# 15 февраля — 4 мая 1914
# 1 ноября 1914
# 5 июня 1914
# 19 ноября 1914
# 26 октября 1914
# 1О, я больше не могу, я задыхаюсь! (фр.)
# 24 октября 1914
# Коктебель, 3 июня 1914
# 3 декабря 1914
# 28 июня 1914
# 30 августа 1914
# 17 июня 1914
# 23 октября 1914
# 4 октября 1914
# 2 января 1914
# 6 декабря 1914
# 13 июля 1914
# Феодосия, 14 февраля 1914
# Декабрь 1914
# 12 июля 1914
# 6 июня 1914
# Москва, 1 декабря 1914
# 16 октября 1914
# Москва, 16 июля 1914
# 25 октября 1914
# 4 сентября 1914
# Горько и стыдно скрываться,
# Не любя, но ценя и за ценного чувствуя боль,
# На правдивый призыв не суметь отозваться, —
# Тяжело мне играть эту первую женскую роль!
# 1913-1914 г.
# 1 июня 1913
# 8 декабря 1913
# Коктебель, 22 мая 1913
# Москва, весна 1913
# 11 июля 1913
# 11 июля 1913
# Коктебель, 13 мая 1913
# 29 мая 1913
# Макс Волошин первый был,
# Нежно Майенку любил,
# Предприимчивый Бальмонт
# Звал с собой за горизонт,
# Вячеслав Иванов сам
# Пел над люлькой по часам:
# Баю-баюшки-баю,
# Баю Майенку мою.
# 1913 г.
# 1 августа 1913
# 11 июля 1913
# Коктебель, 3 мая 1913
# Коктебель, 19 июля 1913
# 17 мая 1913
# 1 октября 1913
# Феодосия, 1913
# Феодосия, Сочельник 1913
# Ялта, 24 сентября 1913
# Феодосия, 26 декабря 1913
# Феодосия, 13 ноября 1913
# Москва, 1912
# Москва, 14 января 1911
# 1«Встречи господина де Брео» Ренье (фр.)
# Брестский вокзал,
# 3 декабря 1911
# Год написания: 1911
# Коктебель, Змеиный грот. 1911
# Гурзуф, Генуэзская крепость,
# апрель 1911
# Гурзуф, 1 мая 1911
# Коктебель, 18 мая 1911
# Коктебель, 13 мая 1911
# 4-9 января 1910
# 9 июня 1910
# Москва, 27 августа 1910
# Год написания: 1910
# Москва. Пасха, 1910
# Москва, осень 1910
# Год написания: 1910
# Weisser Hirsch, лето 1910
# Шолохово, февраль 1910
# Москва, осень, 1910
# Weisser Hirsch, летo 1910
# Москва, 27 ноября 1910
# Берлин, лето 1910
# Москва, Рождество 1909
# Таруса, 26 сентября 1909
# Ceваcтoполь. Пасха, 1909
# Париж, июнь 1909
# Март 1908
# Таруса, лето 1908
# Осень 1908. Москва
# — «Добро любила ль, всем сердцем, страстно?
# Зло — возмущало ль тебя оно?»
# — «О Боже правый, со всем согласна!
# Я так устала. Мне все равно!»
# 1906-1916 г.
# Год написания: 1906-1916
# Уж утро брезжит! Боже мой!
# Полу во сне и полу-бдея
# По мокрым улицам домой
# Мы провожали Чародея.
# 1906-1916 г.
# Что вы, дерзкие, кружитесь, ведь настроен я не кротко.
# Я поклонник бога Вакха, я отныне сам не свой.
# А в соседней зале пели, и покачивалась лодка,
# И смыкались с плеском волны над уставшей головой
# 1906-1916 г.
# Нет возврата. Уж поздно теперь.
# Хоть и страшно, хоть грозный и темный ты,
# Отвори нам желанную дверь,
# Покажи нам заветные комнаты.
# Красен факел у негра в руках,
# Реки света струятся зигзагами…
# Клеопатра ли там в жемчугах?
# Лорелея ли с рейнскими сагами?
# Может быть… — отворяй же скорей
# Тайным знаком серебряной палочки! —
# Там фонтаны из слез матерей?
# И в распущенных косах русалочки?
# Не горящие жаждой уснуть —
# Как несчастны, как жалко-бездомны те!
# Дай нам в душу тебе заглянуть
# В той лиловой, той облачной комнате!
# 1906-1916 г.
# Над миром вечерних видений
# Мы, дети, сегодня цари.
# Спускаются длинные тени,
# Горят за окном фонари,
# Темнеет высокая зала,
# Уходят в себя зеркала…
# Не медлим! Минута настала!
# Уж кто-то идет из угла.
# Нас двое над темной роялью
# Склонилось, и крадется жуть.
# Укутаны маминой шалью,
# Бледнеем, не смеем вздохнуть.
# Посмотрим, что ныне творится
# Под пологом вражеской тьмы?
# Темнее, чем прежде, их лица, —
# Опять победители мы!
# Мы цепи таинственной звенья,
# Нам духом в борьбе не упасть,
# Последнее близко сраженье,
# И темных окончится власть.
# Мы старших за то презираем,
# Что скучны и просты их дни…
# Мы знаем, мы многое знаем
# Того, что не знают они!
# 1906-1916 г.
# Так не зовите их домой
# И не мешайте их стремленьям, —
# Ведь каждый из бойцов — герой!
# Гордитесь юным поколеньем!
# 1906 г.
# 28 февраля 1923
# 17 января 1925
# Батум
# cvetaeva 1365 23537

# %%
for author, poem_text in zip(['cvetaeva'], poems):
    with open('data/'+author+'all.txt', 'w', encoding='UTF-8') as file:
        file.write(poem_text)
    file.close()

# %%
purl
# Out:
# 'http://stih.su//vsyo-tak-zhe-l-osenyayut-svody/'

# %%
get_poem_text(purl)
# Out:
# 1821 г.
# 'всё так же [ль] осеняют своды\n[сей храм] [парнасских] трех цариц?\nвсё те же ль клики юных жриц?\nвсё те же [ль] вьются хороводы?…\nужель умолк волшебный глас\nсеменовой, сей чудной музы?\nужель, навек оставя нас,\nона расторгла с фебом узы,\nи славы русской луч угас?\nне верю! вновь она восстанет.\nей вновь готова дань сердец,\nпред нами долго не [увянет]\nее торжественный венец.\nи для нее любовник [?] славы,\nнаперсник важных аонид [?],\nмладой катенин воскресит\nэсхила гений величавый\nи ей [порфиру] возвратит.\n'

# %%
import re
def get_poem_text(poem_url):
    response = http.request('GET', poem_url)
    c=1
    while response.status != 200 and c<=5:
        response = http.request('GET', poem_url)
        c += 1
    if response.status != 200:
        print('Can\t load the page')
    poem_soup = BeautifulSoup(response.data, "lxml")
    poem_content = poem_soup.find('div', 'entry-content')

    poem_text = ''

    poems_p = poem_content.find_all('p')

    for poem_p in poems_p:
        if poem_p.text.lower().find("год написания") != -1 or re.search(r'18[0-9]+\sг.',poem_p.text):
            print(poem_p.text)
        else:
            
            poem_text+= poem_p.text
            poem_text += '\n'

    poem_text = poem_text.lower()
    return poem_text
